# %% [markdown]
# ### Step 1: Install necesscary packages

# %%
# %pip install -r ../../requirements.txt
# Out:
# Requirement already satisfied: matplotlib in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: torch in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (2.14.0)
# Requirement already satisfied: numpy in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (2.5.3)
# Requirement already satisfied: transformers in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (5.17.0)
# Requirement already satisfied: datasets in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (5.0.1)
# Requirement already satisfied: tiktoken in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (0.14.0)
# Requirement already satisfied: wandb in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (0.30.0)
# Requirement already satisfied: tqdm in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (4.70.1)
# Requirement already satisfied: filelock in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (3.32.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from torch) (2026.6.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (1.31.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (2026.9.10)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (0.23.2)
# Requirement already satisfied: typer in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from transformers) (0.8.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.15.1)
# Requirement already satisfied: certifi in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from datasets) (25.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from datasets) (3.0.5)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from datasets) (2.34.2)
# Requirement already satisfied: xxhash in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from datasets) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (3.14.3)
# Requirement already satisfied: opentelemetry-api>=1.43.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from wandb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.43.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from wandb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.43.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from wandb) (1.44.0)
# Requirement already satisfied: platformdirs in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from wandb) (4.11.8)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>=5 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from wandb) (7.36.1)
# Requirement already satisfied: pydantic<3,>=2.6 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from wandb) (2.13.5)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from pydantic<3,>=2.6->wandb) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from pydantic<3,>=2.6->wandb) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from pydantic<3,>=2.6->wandb) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from requests>=2.32.2->datasets) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from requests>=2.32.2->datasets) (2.8.0)
# Requirement already satisfied: colorama in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (0.5.4)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.25.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.43.0->wandb) (1.75.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.43.0->wandb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.43.0->wandb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from opentelemetry-sdk>=1.43.0->wandb) (0.65b0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from pandas->datasets) (2026.4)
# Requirement already satisfied: six>=1.5 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\jingj\Desktop\SC3000-Assignment-1\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %% [markdown]
# ### Step 2: Package imports and configuration

# %%
import sys
import os
sys.path.append(os.path.abspath("..")) 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import pickle
from model import GPT, GPTConfig
import random
from tqdm import tqdm
import time
import json
import matplotlib.pyplot as plt
# Configuration
beta = 0.5
device = 'cuda' if torch.cuda.is_available() else 'cpu'
base_lr = 1e-4
epochs = 5
batch_size = 64
max_length =64
num_samples = 1
max_new_tokens = 200
temperature = 0.8
top_k = 200
# tokenizer
with open("../sft/meta.pkl", "rb") as f:
    meta = pickle.load(f)
stoi, itos = meta["stoi"], meta["itos"]
def encode(s): return [stoi[c] for c in s]
def decode(l): return ''.join([itos[i] for i in l])

# %% [markdown]
# ### Step 3: Define helper functions

# %%
def compute_logprob(input_ids):
    inputs = input_ids[:, :-1]
    targets = input_ids[:, 1:]
    logits, _ = gpt(inputs, full_seq=True)
    B, T, V = logits.size()
    logits_flat = logits.reshape(-1, V)
    targets_flat = targets.reshape(-1)
    loss = F.cross_entropy(logits_flat, targets_flat, ignore_index=0, reduction='none')
    loss = loss.reshape(B, T)
    attention_mask = (targets != 0).float()
    loss = (loss * attention_mask).sum(dim=1) / attention_mask.sum(dim=1)
    return -loss 

def pad_or_truncate(seq, max_length):
    return seq[-max_length:] if len(seq) > max_length else seq + [0] * (max_length - len(seq))

def get_batches(lines, batch_size):
    random.shuffle(lines)
    #for l in lines:
    #    print(l[1])
    for i in range(0, len(lines), batch_size):
        batch = lines[i:i+batch_size]
        if len(batch) < batch_size:
            continue
        neg_inputs = [pad_or_truncate(encode(p['negative'] + '\n\n\n\n'), max_length) for p in batch]
        pos_inputs = [pad_or_truncate(encode(p['positive'] + '\n\n\n\n'), max_length) for p in batch]
        neg_tensor = torch.tensor(neg_inputs, dtype=torch.long, device=device)
        pos_tensor = torch.tensor(pos_inputs, dtype=torch.long, device=device)
        yield neg_tensor, pos_tensor

# %% [markdown]
# ### Step 4: Load the pretrained NanoGPT model

# %%
ckpt = torch.load("../sft/gpt.pt", map_location=device)
gptconf = GPTConfig(**ckpt['model_args'])
gpt = GPT(gptconf)
state_dict = ckpt['model']
unwanted_prefix = '_orig_mod.'
for k in list(state_dict.keys()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
gpt.load_state_dict(state_dict)
gpt.to(device).train()
# Out:
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(74, 348)
#     (wpe): Embedding(256, 348)
#     (drop): Dropout(p=0.2, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x Block(
#         (ln_1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=348, out_features=1044, bias=False)
#           (c_proj): Linear(in_features=348, out_features=348, bias=False)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (resid_dropout): Dropout(p=0.2, inplace=False)
#         )
#         (ln_2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=348, out_features=1392, bias=False)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1392, out_features=348, bias=False)
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=348, out_features=74, bias=False)
# )

# %% [markdown]
# ### Step 5: Load Data (**students are required to complete this part!**)

# %%
def ask_model(prompt, max_new_tokens=100, temperature=0.7, top_k=20):
    unsupported = sorted(set(prompt) - set(stoi))
    if unsupported:
        raise ValueError(f"Unsupported characters: {unsupported}")

    x = torch.tensor(
        [encode(prompt)],
        dtype=torch.long,
        device=device
    )

    gpt.eval()
    with torch.no_grad():
        generated, _ = gpt.generate(
            x,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            top_k=top_k
        )

    response_tokens = generated[0, x.shape[1]:].tolist()
    return decode(response_tokens)

# %%
print("Kernel works")
print("Configured device:", device)
print("Model device:", next(gpt.parameters()).device)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Kernel works
# Configured device: cpu
# Model device: cpu
# CUDA available: False

# %%
# Load data from ./data/pos_neg_pairs.json

# %%
while True:
    prompt = input("You: ").strip()

    if prompt.lower() in {"quit", "exit"}:
        break

    try:
        answer = ask_model(prompt)
        print("NanoGPT:", answer)
    except ValueError as error:
        print(error)

# %% [markdown]
# ### Step 6: Build the optimizer and scheduler (**students are required to complete this part!**)

# %%
# recommend to use the AdamW optimizer

# %% [markdown]
# ### Step 7: Begin training (**students are required to complete this part!**)

# %%
total_steps = len(lines) // batch_size
for epoch in range(epochs):
    pbar = tqdm(get_batches(lines, batch_size))
    for step, (neg_tensor,pos_tensor) in enumerate(pbar):
        ###########################################################
        # Please complete the training code here!
        # Examples: 
        # ...
        # neg_logprob
        # pos_logprob 
        # loss = -F.logsigmoid((pos_logprob - neg_logprob) / beta).mean() - pos_logprob.mean() * 0.1 
        # ...
        ###########################################################
    ckpt_path = f"./dpo.pt"
    torch.save({
        "model_state_dict": gpt.state_dict(),
        "model_args": ckpt['model_args'],
    }, ckpt_path)
    print(f"Saved checkpoint to {ckpt_path}")

# %% [markdown]
# ### Step 8: Begin testing (**students are required to complete this part!**)

# %%
# Load the fine-tuned model
ckpt_path = "../dpo/dpo.pt"
checkpoint = torch.load(ckpt_path, map_location=device)
gptconf = GPTConfig(**checkpoint['model_args'])
gpt = GPT(gptconf).cuda()
try:
    state_dict = checkpoint['model']
except:
    state_dict = checkpoint['model_state_dict']
unwanted_prefix = '_orig_mod.'
for k,v in list(state_dict.items()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
gpt.load_state_dict(state_dict)
# Test
gpt.eval()
test_set = ["17+19=?", "3*17=?", "72/4=?", "72-x=34,x=?", "x*11=44,x=?", "3*17=?", "72/4=?", "72-x=34,x=?"]
with torch.no_grad():
    for prompt in test_set: 
        prompt_ids = encode(prompt)
        ###########################################################
        # Please complete the test code here!
        # ...
        # gpt.generate(x, max_new_tokens, temperature=temperature, top_k=top_k)
        # ...
        ###########################################################
